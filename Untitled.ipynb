# %%
import requests
import spacy
import json
# Out:
# 2023-11-13 23:25:57.446649: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
nlp = spacy.load("en_core_web_sm")

API_KEY = open('apikey').read()

baltimore_harbor = {
    "circle": {
        "center": {
            "latitude": 39.2820552,
            "longitude": -76.6051076
        },
        "radius": 500
    }
}
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_web_sm' (3.4.0) was trained with spaCy v3.4.0 and may not be 100% compatible with the current version (3.7.0). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
def nearby_places(locationRestriction, url="https://places.googleapis.com/v1/places:searchNearby"):
    body = {
        "maxResultCount": 10,
        "locationRestriction": locationRestriction
    }

    headers = {
        "X-Goog-Api-Key": API_KEY,
        "X-Goog-FieldMask": "places.displayName,places.editorialSummary"
    }
    
    r = requests.post(url, headers=headers, json=body)
    return r.json()

# %%
places = nearby_places(baltimore_harbor)
# places = json.load(open("places"))
places
# Out:
# {'places': [{'displayName': {'text': 'National Aquarium',
#     'languageCode': 'en'},
#    'editorialSummary': {'text': 'Iconic landmark offering marine-life exhibits, a dolphin show, shark tank & walk-through rainforest.',
#     'languageCode': 'en'}},
#   {'displayName': {'text': 'Baltimore Marriott Waterfront',
#     'languageCode': 'en'},
#    'editorialSummary': {'text': 'Modern high-end hotel with a laid-back American restaurant, a 24/7 fitness center & a sauna.',
#     'languageCode': 'en'}},
#   {'displayName': {'text': 'Four Seasons Hotel Baltimore',
#     'languageCode': 'en'},
#    'editorialSummary': {'text': 'A high-end property offering refined rooms & suites, plus a posh day spa, 2 pools & stylish dining.',
#     'languageCode': 'en'}},
#   {'displayName': {'text': 'Baltimore Aquarium', 'languageCode': 'en'}},
#   {'displayName': {'text': 'Rusty Scupper Restaurant & Bar',
#     'languageCode': 'en'},
#    'editorialSummary': {'text': 'Local landmark serving upscale regional seafood dishes in a waterfront setting for over 30 years.',
#     'languageCode': 'en'}},
#   {'displayName': {'text': 'American Visionary Art Museum',
#     'languageCode': 'en'},
#    'editorialSummary': {'text': 'Small museum with unusual rotating exhibits by self-taught artists, plus sculptures & a garden.',
#     'languageCode': 'en'}},
#   {'displayName': {'text': 'Courtyard by Marriott Baltimore Downtown/Inner Harbor',
#     'languageCode': 'en'},
#    'editorialSummary': {'text': 'Modern hotel with an American restaurant, an exercise room & an indoor pool, plus free WiFi.',
#     'languageCode': 'en'}},
#   {'displayName': {'text': 'Hilton Garden Inn Baltimore Inner Harbor',
#     'languageCode': 'en'},
#    'editorialSummary': {'text': 'Modern business hotel with an American restaurant, free WiFi & fitness club passes.',
#     'languageCode': 'en'}},
#   {'displayName': {'text': 'Harbor East Cinemas', 'languageCode': 'en'},
#    'editorialSummary': {'text': 'Movie theater screening new releases as well as independent, foreign & avant-garde flicks.',
#     'languageCode': 'en'}},
#   {'displayName': {'text': 'Pier Six Pavilion', 'languageCode': 'en'},
#    'editorialSummary': {'text': 'Seasonal harborfront pavilion features concerts by household-name bands & performers.',
#     'languageCode': 'en'}}]}

# %%
reviews = {p['displayName']['text']: [i['text']['text'] for i in p['reviews']] for p in places['places']}

# %%
from collections import Counter

reviews_counter = {}
for n, rs in reviews.items():
    adjs = [token.lemma_ for r in rs for token in nlp(r) if token.pos_ == "ADJ"]
    reviews_counter[n] = Counter(adjs)
reviews_counter
# Out:
# {'National Aquarium': Counter({'other': 3,
#           'big': 3,
#           'cool': 3,
#           'great': 3,
#           'hard': 2,
#           'super': 2,
#           'clean': 2,
#           'worth': 2,
#           'beautiful': 2,
#           'busy': 2,
#           'fantastic': 2,
#           'more': 2,
#           'happy': 2,
#           'few': 2,
#           'good': 2,
#           'vertical': 2,
#           'impressive': 1,
#           'surprised': 1,
#           'modern': 1,
#           'easy': 1,
#           'many': 1,
#           'amazing': 1,
#           'entire': 1,
#           'little': 1,
#           'confusing': 1,
#           'wide': 1,
#           'tropical': 1,
#           'worthy': 1,
#           'friendly': 1,
#           'underwater': 1,
#           'huge': 1,
#           'fun': 1,
#           'awesome': 1,
#           'sure': 1,
#           'jellyfish': 1,
#           'hidden': 1,
#           'favorite': 1,
#           'unimpressed': 1,
#           'most': 1,
#           'small': 1,
#           'various': 1,
#           'geographical': 1,
#           'aquatic': 1,
#           'giant': 1,
#           'underwhelming': 1,
#           'front': 1,
#           'late': 1,
#           'enjoyable': 1,
#           'light': 1,
#           'fair': 1,
#           'virtual': 1,
#           'additional': 1}),
#  'Baltimore Marriott Waterfront': Counter({'great': 5,
#           'excellent': 3,
#           'helpful': 2,
#           'personal': 2,
#           'entire': 2,
#           'nice': 2,
#           'large': 2,
#           'offsite': 1,
#           'clean': 1,
#           'comfortable': 1,
#           'accommodating': 1,
#           'fabulous': 1,
#           'kind': 1,
#           'close': 1,
#           'lovely': 1,
#           'awesome': 1,
#           'outstanding': 1,
#           'same': 1,
#           'prompt': 1,
#           'impressed': 1,
#           'worth': 1,
#           'comfy': 1,
#           'prime': 1,
#           'spacious': 1,
#           'expensive': 1,
#           'good': 1,
#           'poor': 1,
#           'tiny': 1,
#           'exhaust': 1,
#           'barn': 1,
#           'thin': 1,
#           'disappointing': 1,
#           'wonderful': 1,
#           'waterfront': 1,
#           'gorgeous': 1,
#           'much': 1,
#           'few': 1,
#           'shifty': 1}),
#  'Four Seasons Hotel Baltimore': Counter({'amazing': 6,
#           'great': 3,
#           'last': 2,
#           'professional': 2,
#           'next': 2,
#           'single': 2,
#           'nice': 2,
#           'young': 1,
#           'perfect': 1,
#           'front': 1,
#           'friendly': 1,
#           'more': 1,
#           'fantastic': 1,
#           'helpful': 1,
#           'happy': 1,
#           'gorgeous': 1,
#           'phenomenal': 1,
#           'stunning': 1,
#           'much': 1,
#           'wonderful': 1,
#           'sure': 1,
#           'many': 1,
#           'little': 1,
#           'awesome': 1}),
#  'Baltimore Aquarium': Counter({'marine': 4,
#           'amazing': 4,
#           'friendly': 3,
#           'worth': 2,
#           'interactive': 2,
#           'educational': 2,
#           'good': 1,
#           'smooth': 1,
#           'live': 1,
#           'other': 1,
#           'healthy': 1,
#           'fun': 1,
#           'fair': 1,
#           'separate': 1,
#           'real': 1,
#           'special': 1,
#           'free': 1,
#           'certain': 1,
#           'well': 1,
#           'actual': 1,
#           'capable': 1,
#           'much': 1,
#           'hard': 1,
#           'stunning': 1,
#           'underwater': 1,
#           'knowledgeable': 1,
#           'willing': 1,
#           'exceptional': 1,
#           'excellent': 1,
#           'interested': 1,
#           'aquatic': 1,
#           'strong': 1,
#           'only': 1,
#           'close': 1,
#           'gorgeous': 1,
#           'personal': 1,
#           'multiple': 1,
#           'endless': 1,
#           'bad': 1,
#           'enough': 1}),
#  'Rusty Scupper Restaurant & Bar': Counter({'amazing': 4,
#           'delicious': 4,
#           'good': 3,
#           'fresh': 2,
#           'top': 2,
#           'mixed': 2,
#           'nice': 2,
#           'pricey': 2,
#           'worth': 2,
#           'different': 2,
#           'cold': 2,
#           'beautiful': 2,
#           'mashed': 2,
#           'kind': 2,
#           'curious': 1,
#           'half': 1,
#           'main': 1,
#           'blackened': 1,
#           'seasonal': 1,
#           'flaky': 1,
#           'everyday': 1,
#           'special': 1,
#           'helpful': 1,
#           'attentive': 1,
#           'small': 1,
#           'daily': 1,
#           'imaginable': 1,
#           'bad': 1,
#           'favorite': 1,
#           'moist': 1,
#           'hot': 1,
#           'great': 1,
#           'creamy': 1,
#           'yum': 1,
#           'ready': 1,
#           'patient': 1}),
#  'American Visionary Art Museum': Counter({'sure': 2,
#           'good': 2,
#           'many': 1,
#           'few': 1,
#           'different': 1,
#           'flawless': 1,
#           'beautiful': 1,
#           'great': 1,
#           'extra': 1,
#           'entire': 1,
#           'rainy': 1,
#           'last': 1,
#           'worried': 1,
#           'natural': 1,
#           'outdoor': 1,
#           'large': 1,
#           'indoor': 1,
#           'contemporary': 1,
#           'unique': 1,
#           'eccentric': 1,
#           '3rd': 1,
#           'idyllic': 1,
#           'huge': 1,
#           'whole': 1,
#           'free': 1,
#           'wonderful': 1,
#           'much': 1,
#           'next': 1,
#           'second': 1,
#           'uncomfortable': 1,
#           'brave': 1,
#           'fantastic': 1,
#           'colorful': 1}),
#  'Courtyard by Marriott Baltimore Downtown/Inner Harbor': Counter({'hot': 4,
#           'special': 2,
#           'clean': 2,
#           'fantastic': 1,
#           'cold': 1,
#           'least': 1,
#           'well': 1,
#           'rude': 1,
#           'sure': 1,
#           'nice': 1,
#           'beautiful': 1,
#           'kind': 1,
#           'helpful': 1,
#           'comfortable': 1,
#           'easy': 1,
#           'great': 1,
#           'old': 1,
#           'worth': 1,
#           'whooping': 1,
#           'good': 1,
#           'excellent': 1,
#           'ill': 1,
#           'front': 1,
#           'freaking': 1,
#           'nuts': 1,
#           'appreciative': 1,
#           'small': 1,
#           'amazing': 1}),
#  'Hilton Garden Inn Baltimore Inner Harbor': Counter({'front': 7,
#           'clean': 4,
#           'short': 4,
#           'great': 3,
#           'same': 3,
#           'more': 3,
#           'bad': 3,
#           'warm': 3,
#           'excellent': 3,
#           'only': 2,
#           'last': 2,
#           'high': 2,
#           'good': 2,
#           'walkable': 1,
#           'separate': 1,
#           'insane': 1,
#           'late': 1,
#           'dead': 1,
#           'asleep': 1,
#           'other': 1,
#           'unacceptable': 1,
#           'next': 1,
#           'full': 1,
#           'subpar': 1,
#           'apologetic': 1,
#           'right': 1,
#           'black': 1,
#           'previous': 1,
#           'worried': 1,
#           'concerned': 1,
#           'far': 1,
#           'disappointing': 1,
#           'random': 1,
#           'old': 1,
#           'outdated': 1,
#           'complimentary': 1,
#           'entire': 1,
#           'major': 1,
#           'daily': 1,
#           'free': 1,
#           'well': 1,
#           'assorted': 1,
#           'cold': 1,
#           'shredded': 1,
#           'most': 1,
#           'frozen': 1,
#           'edible': 1,
#           'exceptional': 1,
#           'several': 1,
#           'convenient': 1,
#           'courteous': 1,
#           'patient': 1,
#           'busy': 1,
#           'sure': 1,
#           'amazing': 1,
#           'fantastic': 1,
#           'easy': 1,
#           'inexpensive': 1,
#           'valet': 1,
#           'nice': 1,
#           'spacious': 1,
#           'inner': 1,
#           'safe': 1}),
#  'Harbor East Cinemas': Counter({'nice': 5,
#           'clean': 3,
#           'other': 2,
#           'new': 2,
#           'more': 2,
#           'friendly': 2,
#           'good': 2,
#           'able': 1,
#           'same': 1,
#           'less': 1,
#           'social': 1,
#           'low': 1,
#           'key': 1,
#           'stylish': 1,
#           'decent': 1,
#           'bad': 1,
#           'personable': 1,
#           'steep': 1,
#           'aware': 1,
#           'mindful': 1,
#           'small': 1,
#           'comfy': 1,
#           'only': 1,
#           'narrow': 1,
#           'ample': 1,
#           'easy': 1,
#           'fancy': 1,
#           'validate': 1,
#           'free': 1,
#           'beautiful': 1,
#           'big': 1,
#           'heated': 1,
#           'helpful': 1,
#           'amazing': 1,
#           'grateful': 1,
#           'honest': 1,
#           'trustworthy': 1}),
#  'Pier Six Pavilion': Counter({'good': 5,
#           'nice': 4,
#           'able': 2,
#           'expensive': 2,
#           'great': 2,
#           'bad': 2,
#           'hidden': 1,
#           'cool': 1,
#           'recent': 1,
#           'other': 1,
#           'efficient': 1,
#           'friendly': 1,
#           'same': 1,
#           'domestic': 1,
#           'pricey': 1,
#           'aware': 1,
#           'grateful': 1,
#           'medical': 1,
#           'sure': 1,
#           'particular': 1,
#           'more': 1,
#           'tight': 1,
#           'beautiful': 1,
#           'right': 1,
#           'clean': 1,
#           'easy': 1,
#           'little': 1,
#           'wise': 1})}

# %%
# place photos: https://developers.google.com/maps/documentation/places/web-service/place-photos

# %%
from openai import OpenAI

# %%
client = OpenAI()

response = client.chat.completions.create(
  model="gpt-4-vision-preview",
  messages=[
    {
      "role": "user",
      "content": [
        {"type": "text", "text": "Give me exactly ten adjectives and no more words that describe this image."},
        {
          "type": "image_url",
          "image_url": {
            "url": "https://lh5.googleusercontent.com/p/AF1QipOiMav2oacyrvkKnQlnHABm0yI3liZQRXRe-QHt=w408-h306-k-no",
          },
        },
      ],
    }
  ],
  max_tokens=300,
)

print(response.choices[0])
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 client = OpenAI()
#       3 response = client.chat.completions.create(
#       4   model="gpt-4-vision-preview",
#       5   messages=[
#    (...)
#      19   max_tokens=300,
#      20 )
#      22 print(response.choices[0])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/openai/_client.py:93, in OpenAI.__init__(self, api_key, organization, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#      91     api_key = os.environ.get("OPENAI_API_KEY")
#      92 if api_key is None:
# ---> 93     raise OpenAIError(
#      94         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#      95     )
#      96 self.api_key = api_key
#      98 if organization is None:
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
